# %%
import numpy as np

reduced_data = np.genfromtxt('X_reduced_401.csv', delimiter = ';')
loadings_data = np.genfromtxt('X_loadings_401.csv', delimiter = ';')

# %%
print(reduced_data.shape)
print(loadings_data.shape)
# Out:
# (100, 10)
# (100, 10)

# %%
X = reduced_data @ loadings_data.T
print(X.shape)
# Out:
# (100, 100)

# %%
import matplotlib.pyplot as plt
plt.imshow(X)

# %%
plt.imshow(X, cmap = 'Greys_r')
